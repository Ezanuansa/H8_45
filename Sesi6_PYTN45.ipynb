# %% [markdown]
# # Explatory Data Analysis with Pandas

# %%
import numpy as np
import pandas as pd

# %%
df_property = pd.read_csv('Data/property_data.csv')
print('num of rows:', df_property.shape[0])
print('num of rows:', df_property.shape[1])
# Out:
# num of rows: 9
# num of rows: 7

# %%
df_property
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df_property.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  8 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 632.0+ bytes

# %%
df_property.loc[df_property["PID"].isna(), "PID"] = 100005000

# %%
df_property["PID"] = df_property["PID"].astype("int")

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY           12            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y           --        1   NaN
# 8  100009000   215.0     TREMONT            Y           na        2  1800

# %%
df_property["OWN_OCCUPIED"]
# Out:
# 0      Y
# 1      N
# 2      N
# 3     12
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
for idx, value in enumerate (df_property["OWN_OCCUPIED"]):
    try:
        int(value)
        df_property.loc[idx, "OWN_OCCUPIED"] = np.nan
    except ValueError:
        print(f"Value {value} is fine! continue..")
# Out:
# Value Y is fine! continue..
# Value N is fine! continue..
# Value N is fine! continue..
# Value Y is fine! continue..
# Value Y is fine! continue..
# Value nan is fine! continue..
# Value Y is fine! continue..
# Value Y is fine! continue..

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y           --        1   NaN
# 8  100009000   215.0     TREMONT            Y           na        2  1800

# %%
df_property.loc[1, "ST_NUM"]
# Out:
# 197.0

# %%
for row, value in enumerate (df_property["NUM_BEDROOMS"]):
    try:
        float(value)
        print(f"Value {value} is fine! continue..")
    except ValueError:
         df_property.loc[row, "NUM_BEDROOMS"] = np.nan
# Out:
# Value 3 is fine! continue..
# Value 3 is fine! continue..
# Value nan is fine! continue..
# Value 1 is fine! continue..
# Value 3 is fine! continue..
# Value nan is fine! continue..
# Value 2 is fine! continue..

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y          NaN        1   NaN
# 8  100009000   215.0     TREMONT            Y          NaN        2  1800

# %%
for row, value in enumerate (df_property["NUM_BATH"]):
    try:
        float(value)
        print(f"Value {value} is fine! continue..")
    except ValueError:
         df_property.loc[row, "NUM_BATH"] = np.nan
# Out:
# Value 1 is fine! continue..
# Value 1.5 is fine! continue..
# Value 1 is fine! continue..
# Value nan is fine! continue..
# Value 2 is fine! continue..
# Value 1 is fine! continue..
# Value 1 is fine! continue..
# Value 2 is fine! continue..

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2      NaN   950
# 7  100008000   213.0     TREMONT            Y          NaN        1   NaN
# 8  100009000   215.0     TREMONT            Y          NaN        2  1800

# %%
for row, value in enumerate (df_property["SQ_FT"]):
    try:
        float(value)
        print(f"Value {value} is fine! continue..")
    except ValueError:
         df_property.loc[row, "SQ_FT"] = np.nan
# Out:
# Value 1000 is fine! continue..
# Value 850 is fine! continue..
# Value 700 is fine! continue..
# Value 1600 is fine! continue..
# Value 800 is fine! continue..
# Value 950 is fine! continue..
# Value nan is fine! continue..
# Value 1800 is fine! continue..

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5   NaN
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2      NaN   950
# 7  100008000   213.0     TREMONT            Y          NaN        1   NaN
# 8  100009000   215.0     TREMONT            Y          NaN        2  1800

# %%
conda install xlrd
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Lenovo\anaconda3\envs\hacktiv8-env
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.12.5          |   py38haa95532_0         141 KB
#     ------------------------------------------------------------
#                                            Total:         141 KB
#
# Note: you may need to restart the kernel to use updated packages.
# The following NEW packages will be INSTALLED:
#
#   xlrd               pkgs/main/noarch::xlrd-1.2.0-py_0
#
# The following packages will be UPDATED:
#
#   certifi                          2020.11.8-py38haa95532_0 --> 2020.12.5-py38haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2020.12.5    | 141 KB    |            |   0%
# certifi-2020.12.5    | 141 KB    | #1         |  11%
# certifi-2020.12.5    | 141 KB    | ##2        |  23%
# certifi-2020.12.5    | 141 KB    | ###4       |  34%
# certifi-2020.12.5    | 141 KB    | ####5      |  45%
# certifi-2020.12.5    | 141 KB    | #######9   |  79%
# certifi-2020.12.5    | 141 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
df_obes = pd.read_excel('Data/obes.xls', sheet_name="7.2", skiprows=4, skipfooter=14)

# %%
df_obes
# Out:
#    Unnamed: 0    Total  Under 16  16-24   25-34   35-44   45-54   55-64  \
# 0         NaN      NaN       NaN    NaN     NaN     NaN     NaN     NaN
# 1     2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0
# 2     2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0
# 3     2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0
# 4     2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0
# 5     2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0
# 6     2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0
# 7     2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0
# 8     2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0
# 9     2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0
# 10    2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0
# 11    2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0
#
#     65-74  75 and over
# 0     NaN          NaN
# 1    52.0         23.0
# 2    52.0         24.0
# 3    36.0         32.0
# 4    72.0         20.0
# 5   118.0         43.0
# 6   157.0         53.0
# 7   221.0         63.0
# 8   378.0         87.0
# 9   456.0        115.0
# 10  468.0         94.0
# 11  495.0         99.0

# %%
df_obes = df_obes.dropna().rename(columns={"Unnamed: 0": "Year"}).set_index("Year")

# %%
df_obes.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df_obes.drop(columns="Total").plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Lenovo\anaconda3\envs\hacktiv8-env
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     freetype-2.10.4            |       hd328e21_0         466 KB
#     kiwisolver-1.3.0           |   py38hd77b12b_0          78 KB
#     lz4-c-1.9.2                |       hf4a77e7_3         106 KB
#     matplotlib-3.3.2           |                0          25 KB
#     matplotlib-base-3.3.2      |   py38hba9282a_0         5.1 MB
#     pillow-8.0.1               |   py38h4fa10fc_0         690 KB
#     zstd-1.4.5                 |       h04227a9_0         456 KB
#     ------------------------------------------------------------
#                                            Total:         6.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/win-64::cycler-0.10.0-py38_0
#   freetype           pkgs/main/win-64::freetype-2.10.4-hd328e21_0
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.3.0-py38hd77b12b_0
#   libtiff            pkgs/main/win-64::libtiff-4.1.0-h56a325e_1
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.2-hf4a77e7_3
#   matplotlib         pkgs/main/win-64::matplotlib-3.3.2-0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.3.2-py38hba9282a_0
#   olefile            pkgs/main/noarch::olefile-0.46-py_0
#   pillow             pkgs/main/win-64::pillow-8.0.1-py38h4fa10fc_0
#   tk                 pkgs/main/win-64::tk-8.6.10-he774522_0
#   xz                 pkgs/main/win-64::xz-5.2.5-h62dcd97_0
#   zstd               pkgs/main/win-64::zstd-1.4.5-h04227a9_0
#
#
#
# Downloading and Extracting Packages
#
# matplotlib-3.3.2     | 25 KB     |            |   0%
# matplotlib-3.3.2     | 25 KB     | ######4    |  65%
# matplotlib-3.3.2     | 25 KB     | ########## | 100%
#
# pillow-8.0.1         | 690 KB    |            |   0%
# pillow-8.0.1         | 690 KB    | ##5        |  25%
# pillow-8.0.1         | 690 KB    | ########5  |  86%
#
# Note: you may need to restart the kernel to use updated packages.
# pillow-8.0.1         | 690 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | 3          |   4%
# matplotlib-base-3.3. | 5.1 MB    | #1         |  12%
# matplotlib-base-3.3. | 5.1 MB    | #7         |  18%
# matplotlib-base-3.3. | 5.1 MB    | ##1        |  22%
# matplotlib-base-3.3. | 5.1 MB    | ##4        |  25%
# matplotlib-base-3.3. | 5.1 MB    | ##7        |  27%
# matplotlib-base-3.3. | 5.1 MB    | ##9        |  30%
# matplotlib-base-3.3. | 5.1 MB    | ###2       |  32%
# matplotlib-base-3.3. | 5.1 MB    | ###3       |  34%
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename C:\Users\Lenovo\anaconda3\envs\hacktiv8-env\Lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans.ttf.  Please remove this file manually (you may need to reboot to free file handles)
# matplotlib-base-3.3. | 5.1 MB    | ###5       |  36%
# matplotlib-base-3.3. | 5.1 MB    | ###7       |  38%
# matplotlib-base-3.3. | 5.1 MB    | ###9       |  39%
# matplotlib-base-3.3. | 5.1 MB    | ####       |  41%
# matplotlib-base-3.3. | 5.1 MB    | ####2      |  42%
# matplotlib-base-3.3. | 5.1 MB    | ####4      |  44%
# matplotlib-base-3.3. | 5.1 MB    | ####5      |  46%
# matplotlib-base-3.3. | 5.1 MB    | ####7      |  47%
# matplotlib-base-3.3. | 5.1 MB    | ####8      |  49%
# matplotlib-base-3.3. | 5.1 MB    | #####      |  51%
# matplotlib-base-3.3. | 5.1 MB    | #####2     |  53%
# matplotlib-base-3.3. | 5.1 MB    | #####4     |  55%
# matplotlib-base-3.3. | 5.1 MB    | #####6     |  57%
# matplotlib-base-3.3. | 5.1 MB    | #####9     |  59%
# matplotlib-base-3.3. | 5.1 MB    | ######1    |  61%
# matplotlib-base-3.3. | 5.1 MB    | ######3    |  63%
# matplotlib-base-3.3. | 5.1 MB    | ######4    |  65%
# matplotlib-base-3.3. | 5.1 MB    | ######6    |  67%
# matplotlib-base-3.3. | 5.1 MB    | ######8    |  69%
# matplotlib-base-3.3. | 5.1 MB    | #######    |  71%
# matplotlib-base-3.3. | 5.1 MB    | #######2   |  72%
# matplotlib-base-3.3. | 5.1 MB    | #######4   |  74%
# matplotlib-base-3.3. | 5.1 MB    | #######6   |  76%
# matplotlib-base-3.3. | 5.1 MB    | #######7   |  78%
# matplotlib-base-3.3. | 5.1 MB    | #######9   |  80%
# matplotlib-base-3.3. | 5.1 MB    | ########1  |  82%
# matplotlib-base-3.3. | 5.1 MB    | ########3  |  83%
# matplotlib-base-3.3. | 5.1 MB    | ########5  |  85%
# matplotlib-base-3.3. | 5.1 MB    | ########7  |  87%
# matplotlib-base-3.3. | 5.1 MB    | ########9  |  89%
# matplotlib-base-3.3. | 5.1 MB    | #########1 |  91%
# matplotlib-base-3.3. | 5.1 MB    | #########3 |  93%
# matplotlib-base-3.3. | 5.1 MB    | #########5 |  95%
# matplotlib-base-3.3. | 5.1 MB    | #########6 |  97%
# matplotlib-base-3.3. | 5.1 MB    | #########8 |  99%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# zstd-1.4.5           | 456 KB    |            |   0%
# zstd-1.4.5           | 456 KB    | #          |  11%
# zstd-1.4.5           | 456 KB    | ###1       |  32%
# zstd-1.4.5           | 456 KB    | #####2     |  53%
# zstd-1.4.5           | 456 KB    | #######3   |  74%
# zstd-1.4.5           | 456 KB    | #########4 |  95%
# zstd-1.4.5           | 456 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 106 KB    |            |   0%
# lz4-c-1.9.2          | 106 KB    | ####5      |  45%
# lz4-c-1.9.2          | 106 KB    | ########## | 100%
#
# freetype-2.10.4      | 466 KB    |            |   0%
# freetype-2.10.4      | 466 KB    | #3         |  14%
# freetype-2.10.4      | 466 KB    | ####1      |  41%
# freetype-2.10.4      | 466 KB    | #######5   |  75%
# freetype-2.10.4      | 466 KB    | ########## | 100%
#
# kiwisolver-1.3.0     | 78 KB     |            |   0%
# kiwisolver-1.3.0     | 78 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
df_obes["Under 16"].plot(label="children < 16 y.o", legend=True)
df_obes["45-54"].plot(label="Adult", legend=True)
df_obes["35-44"].plot(label="35-44", legend=True)
plt.title("Are You Children Getting Father?")
plt.show()

# %%
df_opsd = pd.read_csv('Data/opsd_germany_daily.csv')

# %%
df_opsd.head()
df_opsd.tail()
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
df_opsd["Date"] = pd.to_datetime(df_opsd["Date"])
df_opsd
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar
# 0    2006-01-01   1069.18400      NaN     NaN         NaN
# 1    2006-01-02   1380.52100      NaN     NaN         NaN
# 2    2006-01-03   1442.53300      NaN     NaN         NaN
# 3    2006-01-04   1457.21700      NaN     NaN         NaN
# 4    2006-01-05   1477.13100      NaN     NaN         NaN
# ...         ...          ...      ...     ...         ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df_opsd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %%
df_opsd = df_opsd.set_index("Date")
df_opsd.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
df_opsd["year"] = df_opsd.index.year
df_opsd["month"] = df_opsd.index.month_name()
df_opsd["dayname"] = df_opsd.index.day_name()
df_opsd
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year     month  \
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006   January
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006   January
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006   January
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006   January
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006   January
# ...                 ...      ...     ...         ...   ...       ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017  December
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017  December
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017  December
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017  December
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017  December
#
#               dayname
# Date
# 2006-01-01     Sunday
# 2006-01-02     Monday
# 2006-01-03    Tuesday
# 2006-01-04  Wednesday
# 2006-01-05   Thursday
# ...               ...
# 2017-12-27  Wednesday
# 2017-12-28   Thursday
# 2017-12-29     Friday
# 2017-12-30   Saturday
# 2017-12-31     Sunday
#
# [4383 rows x 7 columns]

# %%
df_opsd.loc['2017/01/01']
# Out:
# Consumption    1130.41
# Wind           307.125
# Solar           35.291
# Wind+Solar     342.416
# year              2017
# month          January
# dayname         Sunday
# Name: 2017-01-01 00:00:00, dtype: object

# %%
df_opsd.loc[df_opsd.index.dayofweek == 0]
df_opsd.loc[df_opsd.dayname == "Monday"]
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year     month dayname
# Date
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006   January  Monday
# 2006-01-09   1529.32300      NaN     NaN         NaN  2006   January  Monday
# 2006-01-16   1563.73800      NaN     NaN         NaN  2006   January  Monday
# 2006-01-23   1569.69100      NaN     NaN         NaN  2006   January  Monday
# 2006-01-30   1554.72200      NaN     NaN         NaN  2006   January  Monday
# ...                 ...      ...     ...         ...   ...       ...     ...
# 2017-11-27   1602.17797  743.280  21.983     765.263  2017  November  Monday
# 2017-12-04   1620.97758  479.798  10.747     490.545  2017  December  Monday
# 2017-12-11   1614.15862  415.109   5.669     420.778  2017  December  Monday
# 2017-12-18   1578.69079  134.843  15.897     150.740  2017  December  Monday
# 2017-12-25   1111.28338  587.810  15.765     603.575  2017  December  Monday
#
# [626 rows x 7 columns]

# %%
set_years = set(df_opsd.index.year)
print("Range of the year:", len(set_years), set_years)
# Out:
# Range of the year: 12 {2016, 2017, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015}

# %%
monthly_avg_opsd = df_opsd.groupby(["year", "month"])[["Consumption", "Wind", "Solar"]].mean()
monthly_avg_opsd
# Out:
#                 Consumption        Wind       Solar
# year month
# 2006 April      1275.058900         NaN         NaN
#      August     1241.188774         NaN         NaN
#      December   1385.686355         NaN         NaN
#      February   1467.106893         NaN         NaN
#      January    1461.442065         NaN         NaN
# ...                     ...         ...         ...
# 2017 March      1422.456871  299.807516  104.216677
#      May        1323.081097  182.150516  165.172774
#      November   1477.990818  341.966700   27.701467
#      October    1366.297385  402.583774   68.727645
#      September  1335.952031  209.591000  102.643033
#
# [144 rows x 3 columns]

# %%
monthly_avg_opsd.loc[[2006, 2007], "Consumption"]
# Out:
# year  month
# 2006  April        1275.058900
#       August       1241.188774
#       December     1385.686355
#       February     1467.106893
#       January      1461.442065
#       July         1253.296290
#       June         1241.781667
#       March        1418.649161
#       May          1253.488484
#       November     1436.164133
#       October      1343.161903
#       September    1311.169933
# 2007  April        1280.133167
#       August       1284.554355
#       December     1400.840161
#       February     1434.484357
#       January      1467.058032
#       July         1281.134258
#       June         1290.828733
#       March        1400.909871
#       May          1265.436000
#       November     1481.237600
#       October      1398.924581
#       September    1347.857500
# Name: Consumption, dtype: float64

# %%
monthly_avg_opsd.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
monthly_avg_opsd.loc[
    ([2006, 2007], ["January", "February"]), 
    ["Consumption", "Wind", "Solar"]
]
# Out:
#                Consumption  Wind  Solar
# year month
# 2006 January   1461.442065   NaN    NaN
#      February  1467.106893   NaN    NaN
# 2007 January   1467.058032   NaN    NaN
#      February  1434.484357   NaN    NaN

# %%
plt.figure(figsize=(12, 6))
df_opsd.loc[df_opsd.index.month < 3, "Consumption"].plot()
plt.show()

# %%
df_opsd.boxplot("Consumption", by= "dayname", figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'Consumption'}, xlabel='dayname'>

# %% [markdown]
# # User Behaviour Data
